# %% [markdown]
# # Toyota Corolla

# %%
# Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %%
#import data
data = pd.read_csv("E:\Assignment\Assignment 5 - Multi linear regression\Toyota_Corolla.csv")
data.head()
# Out:
#    Id  Price  Age     KM  HP    cc  Doors  Cylinders  Gears  Quarterly_Tax  \
# 0   1  13500   23  46986  90  2000      3          4      5            210
# 1   2  13750   23  72937  90  2000      3          4      5            210
# 2   3  13950   24  41711  90  2000      3          4      5            210
# 3   4  14950   26  48000  90  2000      3          4      5            210
# 4   5  13750   30  38500  90  2000      3          4      5            210
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
data.head()
# Out:
#    Id  Price  Age     KM  HP    cc  Doors  Cylinders  Gears  Quarterly_Tax  \
# 0   1  13500   23  46986  90  2000      3          4      5            210
# 1   2  13750   23  72937  90  2000      3          4      5            210
# 2   3  13950   24  41711  90  2000      3          4      5            210
# 3   4  14950   26  48000  90  2000      3          4      5            210
# 4   5  13750   30  38500  90  2000      3          4      5            210
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1436 non-null   int64
#  1   Price          1436 non-null   int64
#  2   Age            1436 non-null   int64
#  3   KM             1436 non-null   int64
#  4   HP             1436 non-null   int64
#  5   cc             1436 non-null   int64
#  6   Doors          1436 non-null   int64
#  7   Cylinders      1436 non-null   int64
#  8   Gears          1436 non-null   int64
#  9   Quarterly_Tax  1436 non-null   int64
#  10  Weight         1436 non-null   int64
# dtypes: int64(11)
# memory usage: 123.5 KB

# %%
# checking missing values
data.isna().sum()
# Out:
# Id               0
# Price            0
# Age              0
# KM               0
# HP               0
# cc               0
# Doors            0
# Cylinders        0
# Gears            0
# Quarterly_Tax    0
# Weight           0
# dtype: int64

# %%
# correlation matrix
data.corr()
# Out:
#                      Id     Price       Age        KM        HP        cc  \
# Id             1.000000 -0.738250  0.906132  0.273298 -0.109375 -0.117704
# Price         -0.738250  1.000000 -0.876590 -0.569960  0.314990  0.126389
# Age            0.906132 -0.876590  1.000000  0.505672 -0.156622 -0.098084
# KM             0.273298 -0.569960  0.505672  1.000000 -0.333538  0.102683
# HP            -0.109375  0.314990 -0.156622 -0.333538  1.000000  0.035856
# cc            -0.117704  0.126389 -0.098084  0.102683  0.035856  1.000000
# Doors         -0.130207  0.185326 -0.148359 -0.036197  0.092424  0.079903
# Cylinders           NaN       NaN       NaN       NaN       NaN       NaN
# Gears         -0.043343  0.063104 -0.005364  0.015023  0.209477  0.014629
# Quarterly_Tax -0.240821  0.219197 -0.198431  0.278165 -0.298432  0.306996
# Weight        -0.414500  0.581198 -0.470253 -0.028598  0.089614  0.335637
#
#                   Doors  Cylinders     Gears  Quarterly_Tax    Weight
# ...

# %% [markdown]
# Scatterplot between variables

# %%
sns.set_style(style='darkgrid')
sns.pairplot(data)

# %% [markdown]
# Preparing a model

# %%
#Built model
import statsmodels.formula.api as smf 
model = smf.ols('Price~Age+KM+HP+cc+Doors+Cylinders+Gears+Quarterly_Tax+Weight',data=data).fit()

# %%
#coefficients
model.params
# Out:
# Intercept        -327.829786
# Age              -121.658402
# KM                 -0.020817
# HP                 31.680906
# cc                 -0.121100
# Doors              -1.616641
# Cylinders       -1311.319143
# Gears             594.319936
# Quarterly_Tax       3.949081
# Weight             16.958632
# dtype: float64

# %%
# Finding p and t values
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept        -3.948666
# Age             -46.511852
# KM              -16.621622
# HP               11.241018
# cc               -1.344222
# Doors            -0.040410
# Cylinders        -3.948666
# Gears             3.016007
# Quarterly_Tax     3.014535
# Weight           15.879803
# dtype: float64
#  Intercept         8.241949e-05
# Age              3.354724e-288
# KM                7.538439e-57
# HP                3.757218e-28
# cc                1.790902e-01
# Doors             9.677716e-01
# Cylinders         8.241949e-05
# Gears             2.606549e-03
# Quarterly_Tax     2.619148e-03
# Weight            2.048576e-52
# dtype: float64

# %%
# R square values
(model.rsquared,model.rsquared_adj)
# Out:
# (0.8637627463428192, 0.8629989775766963)

# %% [markdown]
# Simple Linear Regression

# %%
ml=smf.ols('Price~Age',data = data).fit()  
print(ml.tvalues, '\n', ml_v.pvalues)
# Out:
# Intercept    138.907847
# Age          -68.978267
# dtype: float64
#  Intercept    1.239303e-290
# Age           0.000000e+00
# KM            5.539700e-17
# HP            1.479626e-33
# dtype: float64

# %%
m2=smf.ols('Price~KM',data = data).fit()  
print(m2.tvalues, '\n', ml_v.pvalues)
# Out:
# Intercept    88.510378
# KM          -26.267601
# dtype: float64
#  Intercept    1.239303e-290
# Age           0.000000e+00
# KM            5.539700e-17
# HP            1.479626e-33
# dtype: float64

# %%
m3=smf.ols('Price~HP',data = data).fit()  
print(m3.tvalues, '\n', ml_v.pvalues)
# Out:
# Intercept     4.803134
# HP           12.567862
# dtype: float64
#  Intercept    1.239303e-290
# Age           0.000000e+00
# KM            5.539700e-17
# HP            1.479626e-33
# dtype: float64

# %%
ml23=smf.ols('Price~Age+KM+HP',data = data).fit()  
print(ml23.tvalues, '\n', ml_v.pvalues)
# Out:
# Intercept    46.771051
# Age         -59.432324
# KM           -8.479736
# HP           12.388317
# dtype: float64
#  Intercept    1.239303e-290
# Age           0.000000e+00
# KM            5.539700e-17
# HP            1.479626e-33
# dtype: float64

# %% [markdown]
# Calculating VIF

# %%
rsq_Age = smf.ols('Age~KM+HP+cc+Doors+Cylinders+Gears+Quarterly_Tax+Weight',data=data).fit().rsquared
vif_Age = 1/(1-rsq_Age)

rsq_KM = smf.ols('KM~Age+HP+cc+Doors+Cylinders+Gears+Quarterly_Tax+Weight',data=data).fit().rsquared  
vif_KM = 1/(1-rsq_KM)

rsq_HP = smf.ols('HP~Age+KM+cc+Doors+Cylinders+Gears+Quarterly_Tax+Weight',data=data).fit().rsquared  
vif_HP = 1/(1-rsq_HP)

rsq_cc = smf.ols('cc~Age+KM+HP+Doors+Cylinders+Gears+Quarterly_Tax+Weight',data=data).fit().rsquared  
vif_cc = 1/(1-rsq_cc)

rsq_Doors = smf.ols('Doors~Age+KM+HP+cc+Cylinders+Gears+Quarterly_Tax+Weight',data=data).fit().rsquared  
vif_Doors = 1/(1-rsq_Doors)

rsq_Cylinders = smf.ols('Cylinders~Age+KM+HP+cc+Doors+Cylinders+Gears+Quarterly_Tax+Weight',data=data).fit().rsquared  
vif_Cylinders = 1/(1-rsq_Cylinders)


rsq_Gears = smf.ols('Gears~Age+KM+HP+cc+Doors+Cylinders+Quarterly_Tax+Weight',data=data).fit().rsquared  
vif_Gears = 1/(1-rsq_Gears)

rsq_Quarterly_Tax = smf.ols('Quarterly_Tax~Age+KM+HP+cc+Doors+Cylinders+Gears+Weight',data=data).fit().rsquared  
vif_Quarterly_Tax = 1/(1-rsq_Quarterly_Tax)

rsq_Weight = smf.ols('Weight~Age+KM+HP+cc+Doors+Cylinders+Gears+Quarterly_Tax',data=data).fit().rsquared  
vif_Weight = 1/(1-rsq_Weight)


# Storing vif values in a data frame
d1 = {'Variables':['Age','KM','HP','cc','Doors','Cylinders','Gears','Quarterly_Tax','Weight'],'VIF':[vif_Age,vif_KM,vif_HP,vif_cc,vif_Doors,vif_Cylinders,vif_Gears,vif_Quarterly_Tax,vif_Weight]}
Vif_frame = pd.DataFrame(d1)  
Vif_frame
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#        Variables       VIF
# 0            Age  1.884620
# 1             KM  1.756905
# 2             HP  1.419422
# 3             cc  1.163894
# 4          Doors  1.156575
# 5      Cylinders  0.000000
# 6          Gears  1.098723
# 7  Quarterly_Tax  2.311431
# 8         Weight  2.516420

# %%
# None variable has VIF>20, No Collinearity, so consider all varaibles in Regression equation

# %% [markdown]
# # Residual Analysis

# %%
# Test for normality of Residuals(Q-Q plot)
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid>6000))
# Out:
# [array([147, 523], dtype=int64)]

# %%
list(np.where(model.resid<-6000))
# Out:
# [array([221, 601, 960], dtype=int64)]

# %%
# Test for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Age", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "KM", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "HP", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "cc", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Doors", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Gears", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Quarterly_Tax", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Weight", fig=fig)
plt.show()

# %% [markdown]
# Model Deletion Diagnostics

# %% [markdown]
# Detecting Influencers/Outliers

# %% [markdown]
# Cook’s Distance

# %%
# 1. Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance
c
# Out:
# array([6.51314400e-03, 3.57114053e-03, 4.91829106e-03, ...,
#        7.60286119e-07, 6.28090532e-04, 9.77649517e-03])

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(data)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
#index and value of influencer where c is more than .5
(np.argmax(c),np.max(c))
# Out:
# (80, 71.56809561714256)

# %% [markdown]
# High Influence points

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k = data.shape[1]
n = data.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.02506963788300836

# %% [markdown]
# From the above plot, it is evident that data point 80 is the influencer

# %%
data[data.index.isin([80])]
# Out:
#     Id  Price  Age     KM   HP     cc  Doors  Cylinders  Gears  Quarterly_Tax  \
# 80  81  18950   25  20019  110  16000      5          4      5            100
#
#     Weight
# 80    1180

# %%
#See the differences in HP and other variable v
data.head()
# Out:
#    Id  Price  Age     KM  HP    cc  Doors  Cylinders  Gears  Quarterly_Tax  \
# 0   1  13500   23  46986  90  2000      3          4      5            210
# 1   2  13750   23  72937  90  2000      3          4      5            210
# 2   3  13950   24  41711  90  2000      3          4      5            210
# 3   4  14950   26  48000  90  2000      3          4      5            210
# 4   5  13750   30  38500  90  2000      3          4      5            210
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %% [markdown]
# Improving the model

# %%
# load the data
data_new = pd.read_csv("E:\Assignment\Assignment 5 - Multi linear regression\Toyota_Corolla.csv")

# %%
#Discard the data points which are influencers and reasign the row number (reset_index())
data1 = data_new.drop(data_new.index[[80]],axis=0).reset_index()

# %%
#Drop the original index
data1=data1.drop(['index'],axis=1)

# %%
data1
# Out:
#         Id  Price  Age     KM   HP    cc  Doors  Cylinders  Gears  \
# 0        1  13500   23  46986   90  2000      3          4      5
# 1        2  13750   23  72937   90  2000      3          4      5
# 2        3  13950   24  41711   90  2000      3          4      5
# 3        4  14950   26  48000   90  2000      3          4      5
# 4        5  13750   30  38500   90  2000      3          4      5
# ...    ...    ...  ...    ...  ...   ...    ...        ...    ...
# 1430  1438   7500   69  20544   86  1300      3          4      5
# 1431  1439  10845   72  19000   86  1300      3          4      5
# 1432  1440   8500   71  17016   86  1300      3          4      5
# 1433  1441   7250   70  16916   86  1300      3          4      5
# 1434  1442   6950   76      1  110  1600      5          4      5
#
#       Quarterly_Tax  Weight
# 0               210    1165
# 1               210    1165
# 2               210    1165
# 3               210    1165
# ...

# %% [markdown]
# Build Model

# %%
while model.rsquared < 0.90:
    for c in [np.max(c)>0.5]:
        model=smf.ols('Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=data1).fit()
        (c,_)=model.get_influence().cooks_distance
        c
        np.argmax(c) , np.max(c)
        data1=data1.drop(data1.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
        data1
    else:
        final_model=smf.ols('Price~Age+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=data1).fit()
        final_model.rsquared , final_model.aic
        print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.8778445878599779
# Thus model accuracy is improved to 0.8851845904421739
# Thus model accuracy is improved to 0.8894191849749751
# Thus model accuracy is improved to 0.8914204825569462
# Thus model accuracy is improved to 0.8921467826162199
# Thus model accuracy is improved to 0.8934037497368834
# Thus model accuracy is improved to 0.8944954473640403
# Thus model accuracy is improved to 0.8958333530393431
# Thus model accuracy is improved to 0.8966334481080778
# Thus model accuracy is improved to 0.8941835374074523
# Thus model accuracy is improved to 0.8951069956497651
# Thus model accuracy is improved to 0.8965514940097825
# Thus model accuracy is improved to 0.8971531368893259
# Thus model accuracy is improved to 0.8979680072945878
# Thus model accuracy is improved to 0.8975421185310548
# Thus model accuracy is improved to 0.8970095523065386
# Thus model accuracy is improved to 0.8965434597967323
# ...

# %%
(final_model.rsquared,final_model.aic)
# Out:
# (0.9003762532318559, 22093.157808007065)

# %%
data1
# Out:
#         Id  Price  Age     KM  HP    cc  Doors  Cylinders  Gears  \
# 0        2  13750   23  72937  90  2000      3          4      5
# 1        4  14950   26  48000  90  2000      3          4      5
# 2        5  13750   30  38500  90  2000      3          4      5
# 3        6  12950   32  61000  90  2000      3          4      5
# 4        7  16900   27  94612  90  2000      3          4      5
# ...    ...    ...  ...    ...  ..   ...    ...        ...    ...
# 1325  1437   8450   80  23000  86  1300      3          4      5
# 1326  1438   7500   69  20544  86  1300      3          4      5
# 1327  1439  10845   72  19000  86  1300      3          4      5
# 1328  1440   8500   71  17016  86  1300      3          4      5
# 1329  1441   7250   70  16916  86  1300      3          4      5
#
#       Quarterly_Tax  Weight
# 0               210    1165
# 1               210    1165
# 2               210    1170
# 3               210    1170
# 4               210    1245
# ...

# %% [markdown]
# Model Predictions

# %%
# say New data for prediction is
new_data=pd.DataFrame({'Age':22,"KM":40000,"HP":85,"cc":1300,"Doors":4,"Gears":5,"Cylinders":4,"Quarterly_Tax":69,"Weight":1012},index=[0])
new_data
# Out:
#    Age     KM  HP    cc  Doors  Gears  Cylinders  Quarterly_Tax  Weight
# 0   22  40000  85  1300      4      5          4             69    1012

# %%
# Manual Prediction of Price
final_model.predict(new_data)
# Out:
# 0    13355.508788
# dtype: float64

# %%
# Automatic Prediction of Price with 90.03% accurcy
pred_y=final_model.predict(data1)
pred_y
# Out:
# 0       15354.362106
# 1       15415.237858
# 2       15314.008799
# 3       14749.534289
# 4       17544.273936
#             ...
# 1325     7607.457292
# 1326     9206.037539
# 1327     8535.375501
# 1328     8674.315161
# 1329     8784.118985
# Length: 1330, dtype: float64

# %% [markdown]
# # 50_Startups Data

# %%
# Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %%
#import data
data = pd.read_csv("E:\Assignment\Assignment 5 - Multi linear regression\Startups.csv")
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
# Renaming
data1=data.rename({'R&D Spend':'RDS','Administration':'ADMS','Marketing Spend':'MKTS'},axis=1)
data1.head()
# Out:
#          RDS       ADMS       MKTS       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
data1.describe()
# Out:
#                  RDS           ADMS           MKTS         Profit
# count      50.000000      50.000000      50.000000      50.000000
# mean    73721.615600  121344.639600  211025.097800  112012.639200
# std     45902.256482   28017.802755  122290.310726   40306.180338
# min         0.000000   51283.140000       0.000000   14681.400000
# 25%     39936.370000  103730.875000  129300.132500   90138.902500
# 50%     73051.080000  122699.795000  212716.240000  107978.190000
# 75%    101602.800000  144842.180000  299469.085000  139765.977500
# max    165349.200000  182645.560000  471784.100000  192261.830000

# %%
# checking missing values
data1.isna().sum()
# Out:
# RDS       0
# ADMS      0
# MKTS      0
# State     0
# Profit    0
# dtype: int64

# %%
# correlation matrix
data1.corr()
# Out:
#              RDS      ADMS      MKTS    Profit
# RDS     1.000000  0.241955  0.724248  0.972900
# ADMS    0.241955  1.000000 -0.032154  0.200717
# MKTS    0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %% [markdown]
# Scatterplot between variable

# %%
sns.set_style(style='darkgrid')
sns.pairplot(data1)

# %% [markdown]
# Preparing Model

# %%
#Built model
import statsmodels.formula.api as smf 
model = smf.ols('Profit~RDS+ADMS+MKTS',data=data1).fit()

# %%
#coefficients
model.params
# Out:
# Intercept    50122.192990
# RDS              0.805715
# ADMS            -0.026816
# MKTS             0.027228
# dtype: float64

# %%
# Finding p and t values
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept     7.626218
# RDS          17.846374
# ADMS         -0.525507
# MKTS          1.655077
# dtype: float64
#  Intercept    1.057379e-09
# RDS          2.634968e-22
# ADMS         6.017551e-01
# MKTS         1.047168e-01
# dtype: float64

# %%
# R square values
(model.rsquared,model.rsquared_adj)
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %% [markdown]
# Simple Linear Regression

# %%
ml=smf.ols('Profit~ADMS',data = data1).fit()  
print(ml.tvalues, '\n', ml.pvalues)
# Out:
# Intercept    3.040044
# ADMS         1.419493
# dtype: float64
#  Intercept    0.003824
# ADMS         0.162217
# dtype: float64

# %%
m2=smf.ols('Profit~MKTS',data = data1).fit()  
print(ml.tvalues, '\n', ml.pvalues)
# Out:
# Intercept    3.040044
# ADMS         1.419493
# dtype: float64
#  Intercept    0.003824
# ADMS         0.162217
# dtype: float64

# %%
m12=smf.ols('Profit~ADMS+MKTS',data = data1).fit()  
print(ml.tvalues, '\n', ml.pvalues)
# Out:
# Intercept    3.040044
# ADMS         1.419493
# dtype: float64
#  Intercept    0.003824
# ADMS         0.162217
# dtype: float64

# %% [markdown]
# Calculating VIF

# %%
rsq_RDS=smf.ols("RDS~ADMS+MKTS",data=data1).fit().rsquared
vif_RDS=1/(1-rsq_RDS)

rsq_ADMS=smf.ols("ADMS~RDS+MKTS",data=data1).fit().rsquared
vif_ADMS=1/(1-rsq_ADMS)

rsq_MKTS=smf.ols("MKTS~RDS+ADMS",data=data1).fit().rsquared
vif_MKTS=1/(1-rsq_MKTS)

# Putting the values in Dataframe format
d1={'Variables':['RDS','ADMS','MKTS'],'Vif':[vif_RDS,vif_ADMS,vif_MKTS]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0       RDS  2.468903
# 1      ADMS  1.175091
# 2      MKTS  2.326773

# %%
# None variable has VIF>20, No Collinearity, so consider all varaibles in Regression equation

# %% [markdown]
# Residual Analysis

# %%
# Test for normality of Residuals(Q-Q plot)
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid< -30000))
# Out:
# [array([49], dtype=int64)]

# %%
# Test for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "RDS", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "ADMS", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "MKTS", fig=fig)
plt.show()

# %% [markdown]
# Model Deletion Diagnostics

# %%
# 1. Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(data)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
#index and value of influencer where c is more than .5
(np.argmax(c),np.max(c))
# Out:
# (49, 0.28808229275432634)

# %% [markdown]
# High Influence points

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()
# From the plot, it is evident that data point 49 is the influencer

# %%
k = data.shape[1]
n = data.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.36

# %%
data1[data1.index.isin([49])]
# Out:
#     RDS      ADMS      MKTS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %%
#See the differences in HP and other variable v
data1.head()
# Out:
#          RDS       ADMS       MKTS       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %% [markdown]
# Improving the model

# %%
#Discard the data points which are influencers and reasign the row number (reset_index())
data2 = data1.drop(data1.index[[49]],axis=0).reset_index()

# %%
data2
# Out:
#     index        RDS       ADMS       MKTS       State     Profit
# 0       0  165349.20  136897.80  471784.10    New York  192261.83
# 1       1  162597.70  151377.59  443898.53  California  191792.06
# 2       2  153441.51  101145.55  407934.54     Florida  191050.39
# 3       3  144372.41  118671.85  383199.62    New York  182901.99
# 4       4  142107.34   91391.77  366168.42     Florida  166187.94
# 5       5  131876.90   99814.71  362861.36    New York  156991.12
# 6       6  134615.46  147198.87  127716.82  California  156122.51
# 7       7  130298.13  145530.06  323876.68     Florida  155752.60
# 8       8  120542.52  148718.95  311613.29    New York  152211.77
# 9       9  123334.88  108679.17  304981.62  California  149759.96
# 10     10  101913.08  110594.11  229160.95     Florida  146121.95
# 11     11  100671.96   91790.61  249744.55  California  144259.40
# 12     12   93863.75  127320.38  249839.44     Florida  141585.52
# ...

# %% [markdown]
# Build Model

# %%
while np.max(c)>0.5 :
    model=smf.ols("Profit~RDS+ADMS+MKTS",data=data2).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    data2=data2.drop(data2.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    data2
else:
    final_model=smf.ols("Profit~RDS+ADMS+MKTS",data=data2).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
# Out:
# Thus model accuracy is improved to 0.9613162435129847

# %%
(final_model.rsquared,final_model.aic)
# Out:
# (0.9613162435129847, 1020.5652974526367)

# %%
data2
# Out:
#     index        RDS       ADMS       MKTS       State     Profit
# 0       0  165349.20  136897.80  471784.10    New York  192261.83
# 1       1  162597.70  151377.59  443898.53  California  191792.06
# 2       2  153441.51  101145.55  407934.54     Florida  191050.39
# 3       3  144372.41  118671.85  383199.62    New York  182901.99
# 4       4  142107.34   91391.77  366168.42     Florida  166187.94
# 5       5  131876.90   99814.71  362861.36    New York  156991.12
# 6       6  134615.46  147198.87  127716.82  California  156122.51
# 7       7  130298.13  145530.06  323876.68     Florida  155752.60
# 8       8  120542.52  148718.95  311613.29    New York  152211.77
# 9       9  123334.88  108679.17  304981.62  California  149759.96
# 10     10  101913.08  110594.11  229160.95     Florida  146121.95
# 11     11  100671.96   91790.61  249744.55  California  144259.40
# 12     12   93863.75  127320.38  249839.44     Florida  141585.52
# ...

# %% [markdown]
# Model Predictions

# %%
# say New data for prediction is
new_data=pd.DataFrame({'RDS':85000,"ADMS":95000,"MKTS":141000},index=[0])
new_data
# Out:
#      RDS   ADMS    MKTS
# 0  85000  95000  141000

# %%
# Manual Prediction of Profit
final_model.predict(new_data)
# Out:
# 0    120386.409613
# dtype: float64

# %%
# Automatic Prediction of Price with 96.13% accurcy
pred_y=final_model.predict(data1)
pred_y
# Out:
# 0     190716.676999
# 1     187537.122227
# 2     180575.526396
# 3     172461.144642
# 4     170863.486721
# 5     162582.583177
# 6     157741.338633
# 7     159347.735318
# 8     151328.826941
# 9     154236.846778
# 10    135507.792682
# 11    135472.855621
# 12    129355.599449
# 13    127780.129139
# 14    149295.404796
# 15    145937.941975
# 16    117437.627921
# 17    130408.626295
# 18    129129.234457
# 19    116641.003121
# 20    117097.731866
# 21    117911.019038
# 22    115248.217796
# 23    110603.139045
# 24    114051.073877
# 25    103398.054385
# 26    111547.638935
# 27    114916.165026
# 28    103027.229434
# 29    103057.621761
# 30    100656.410227
# 31     99088.213693
# 32    100325.741335
# 33     98962.303136
# 34     90552.307809
# 35     91709.288672
# 36     77080.554255
# 37     90722.503244
# 38     71433.021956
# 39     85147.375646
# 40     76625.510303
# 41     76492.145175
# 42     72492.394974
# 43     62592.049718
# 44     67025.731107
# ...
