# %% [markdown]
# ## Salary Data

# %%
#Importing the libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing

# %%
#Importing data
salary_train = pd.read_csv('E:\Assignment\Assignment 12 - Naive bayes\SalaryData_Train.csv')
salary_test = pd.read_csv('E:\Assignment\Assignment 12 - Naive bayes\SalaryData_Test.csv')

# %%
salary_train.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male         2174
# 1     Exec-managerial         Husband   White     Male            0
# 2   Handlers-cleaners   Not-in-family   White     Male            0
# 3   Handlers-cleaners         Husband   Black     Male            0
# 4      Prof-specialty            Wife   Black   Female            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
salary_test.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# ...

# %%
#Preprocessing
from sklearn import preprocessing
number = preprocessing.LabelEncoder()

# %%
string_columns=["workclass","education","maritalstatus","occupation","relationship","race","sex","native"]
for i in string_columns:
    salary_train[i] = number.fit_transform(salary_train[i])
    salary_test[i] = number.fit_transform(salary_test[i])

# %%
colnames = salary_train.columns
colnames
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
len(colnames[0:13])
# Out:
# 13

# %%
# Splitting data into train and test
trainX = salary_train[colnames[0:13]]
trainY = salary_train[colnames[13]]
testX  = salary_test[colnames[0:13]]
testY  = salary_test[colnames[13]]

# %% [markdown]
# # Gaussian

# %%
gnb = GaussianNB()

# %%
# Building Model
build_gnb = gnb.fit(trainX,trainY)

# %%
# Predicting Model
pred_gnb= build_gnb.predict(testX)

# %%
# Confusion matrix GaussianNB model
confusion_matrix(testY,pred_gnb)
# Out:
# array([[10759,   601],
#        [ 2491,  1209]], dtype=int64)

# %%
print ("Accuracy",(10759+1209)/(10759+601+2491+1209))
# Out:
# Accuracy 0.7946879150066402

# %%
# In Gaussian classifier we are obtaining Accuracy nearly 80%

# %% [markdown]
# # Multinomial

# %%
mnb = MultinomialNB()

# %%
# Building Model
build_mnb = gnb.fit(trainX,trainY)

# %%
# Predicting Model
pred_mnb= build_mnb.predict(testX)

# %%
# Confusion matrix MultinominalNB model
confusion_matrix(testY,pred_mnb)
# Out:
# array([[10759,   601],
#        [ 2491,  1209]], dtype=int64)

# %%
print("Accuracy",(10891+780)/(10891+780+2920+780))
# Out:
# Accuracy 0.7592869689675362

# %%
# In Multinominal classifier we are obtaining Accuracy nearly 76%
